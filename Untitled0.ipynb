# %% [markdown]
# <a href="https://colab.research.google.com/github/Karolinasieci/introtopython/blob/grupa--2/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# sieci -z2- Grupa2- 2.03.2020

# %%
x = 10
x = x + 7

# %%
print (x)
# Out:
# 17

# %%
y = 3
y = y - 1

# %%
print (y)
# Out:
# 2

# %%
i = 5
i = i * "3.120"

# %%
print (i)
# Out:
# 3.1203.1203.1203.1203.120

# %%
t = 12
t = t / 6

# %%
print (t)
# Out:
# 2.0

# %%
r = 4
r = 4** 2

# %%
print (r)
# Out:
# 16

# %% [markdown]
# notatki PODSTAWOWE OPERACJE ARTMETYCZNE

# %%
Sala = "3.120"
Sala = Sala * 2

# %%
print (Sala)
# Out:
# 3.1203.120

# %% [markdown]
# NAZWY ZMIENNYCH
# ‒	Muszą zaczynać się od litery lub podkreślenia
# ‒	Mogą zawierać litery, cyfry, podkreślenia (bez polskich znaków)
# ‒	Wielkość znaków ma znaczenie
# ‒	Pewne słowa są zarezerwowane np. do funkcji i metod  tych zarezerwowanych słów nie stosuje się do nazywania zmiennych
# ‒	Nazwy zmiennych mają nieść znaczenie!

# %%
type (3)
# Out:
# int

# %%
type (4.5)
# Out:
# float

# %%
type ("Dog Rescure")
# Out:
# str

# %%
obecność  = True
type (obecność)
# Out:
# bool

# %%
3==7
# Out:
# False

# %%
3 !=3
# Out:
# False

# %%
3 !=8
# Out:
# True

# %% [markdown]
# ODSTAWOWE TYPY DANYCH w Pythonie
# ‒	Integers	int
# ‒	Floats		float
# ‒	Strings		str
# ‒	Boolean	bool
# ‒	Long
# ‒	Complex
# ‒	Datetime

# %% [markdown]
#  len -Zwraca długość obiektu (liczbę elementów) obiektu. Argumentem może być sekwencja (taka jak ciąg, bajty, krotka, lista lub zakres) lub kolekcja (taka jak słownik, zestaw lub zestaw zamrożony).

# %%
len ("Sieci")
# Out:
# 5

# %%
len ("Sieci 2 ")
# Out:
# 8

# %%
len (37)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-779285db1d0f> in <module>()
# ----> 1 len (37)
#
# TypeError: object of type 'int' has no len()

# %%
#tworzę liste org - []
org = ["Dog Rescue", "Animal Patrol", "KTOZ"]
len (org)
# Out:
# 3
